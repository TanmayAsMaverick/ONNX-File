# %%
# !pip install rarfile

# %%
import rarfile
rar= rarfile.RarFile("/content/new.rar")
rar.extractall("/content")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import rarfile
# ----> 2 rar= rarfile.RarFile("/content/new.rar")
#       3 rar.extractall("/content")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rarfile.py:711, in RarFile.__init__(self, file, mode, charset, info_callback, crc_check, errors, part_only)
#     708 if mode != "r":
#     709     raise NotImplementedError("RarFile supports only mode=r")
# --> 711 self._parse()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rarfile.py:918, in RarFile._parse(self)
#     915 def _parse(self):
#     916     """Run parser for file type
#     917     """
# --> 918     ver, sfx_ofs = _find_sfx_header(self._rarfile)
# ...
